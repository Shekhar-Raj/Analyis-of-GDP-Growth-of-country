# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import plotly.offline as pyo

# %%
df=pd.read_csv("gdp.txt")
df
# Out:
#       Country Name Country Code  Year         Value
# 0       Arab World          ARB  1968  2.576068e+10
# 1       Arab World          ARB  1969  2.843420e+10
# 2       Arab World          ARB  1970  3.138550e+10
# 3       Arab World          ARB  1971  3.642691e+10
# 4       Arab World          ARB  1972  4.331606e+10
# ...            ...          ...   ...           ...
# 11502     Zimbabwe          ZWE  2012  1.424249e+10
# 11503     Zimbabwe          ZWE  2013  1.545177e+10
# 11504     Zimbabwe          ZWE  2014  1.589105e+10
# 11505     Zimbabwe          ZWE  2015  1.630467e+10
# 11506     Zimbabwe          ZWE  2016  1.661996e+10
#
# [11507 rows x 4 columns]

# %%
df['Country Name'].unique()
# Out:
# array(['Arab World', 'Caribbean small states',
#        'Central Europe and the Baltics', 'Early-demographic dividend',
#        'East Asia & Pacific',
#        'East Asia & Pacific (excluding high income)',
#        'East Asia & Pacific (IDA & IBRD countries)', 'Euro area',
#        'Europe & Central Asia',
#        'Europe & Central Asia (excluding high income)',
#        'Europe & Central Asia (IDA & IBRD countries)', 'European Union',
#        'Fragile and conflict affected situations',
#        'Heavily indebted poor countries (HIPC)', 'High income',
#        'IBRD only', 'IDA & IBRD total', 'IDA blend', 'IDA only',
#        'IDA total', 'Late-demographic dividend',
#        'Latin America & Caribbean',
#        'Latin America & Caribbean (excluding high income)',
#        'Latin America & the Caribbean (IDA & IBRD countries)',
#        'Least developed countries: UN classification',
#        'Low & middle income', 'Low income', 'Lower middle income',
# ...

# %% [markdown]
# # To Find GDP Growth of every country Together

# %%
final_data=[]
for country_name in df["Country Name"]:
    df_pr=df[df["Country Name"]==country_name]
    data=df_pr.values
    gdp_change=[0]
    for i in range(1,len(data)):
        prev=data[i-1][3]
        cur=data[i][3]
        gdp_change.append(round(((cur-prev)/prev)*100,2))
    df_pr=df_pr.assign(GDP=gdp_change)
    final_data.append(df_pr)

# %%
df=pd.concat(final_data,axis=0)

# %%
df.head
# Out:
# <bound method NDFrame.head of       Country Name Country Code  Year         Value    GDP
# 0       Arab World          ARB  1968  2.576068e+10   0.00
# 1       Arab World          ARB  1969  2.843420e+10  10.38
# 2       Arab World          ARB  1970  3.138550e+10  10.38
# 3       Arab World          ARB  1971  3.642691e+10  16.06
# 4       Arab World          ARB  1972  4.331606e+10  18.91
# ...            ...          ...   ...           ...    ...
# 11502     Zimbabwe          ZWE  2012  1.424249e+10  17.72
# 11503     Zimbabwe          ZWE  2013  1.545177e+10   8.49
# 11504     Zimbabwe          ZWE  2014  1.589105e+10   2.84
# 11505     Zimbabwe          ZWE  2015  1.630467e+10   2.60
# 11506     Zimbabwe          ZWE  2016  1.661996e+10   1.93
#
# [571737 rows x 5 columns]>

# %%
df.groupby("Country Name").max()["GDP"].sort_values(ascending=False)
# Out:
# Country Name
# Switzerland          479.82
# Equatorial Guinea    409.33
# Cambodia             330.58
# Congo, Dem. Rep.     305.16
# Oman                 240.75
#                       ...
# Barbados              12.76
# North America         12.14
# Aruba                 11.01
# Guam                   8.82
# Somalia                5.51
# Name: GDP, Length: 256, dtype: float64

# %% [markdown]
# # Here we can see the total gdp of world that is sum of all countries gdp.

# %%
df.groupby("Country Name").max()["Value"].sort_values(ascending=False)
# Out:
# Country Name
# World                        7.904923e+13
# High income                  5.036240e+13
# OECD members                 4.937008e+13
# Post-demographic dividend    4.673504e+13
# IDA & IBRD total             2.948247e+13
#                                  ...
# Palau                        3.102483e+08
# Marshall Islands             1.944979e+08
# Kiribati                     1.880457e+08
# Nauru                        1.170204e+08
# Tuvalu                       3.987575e+07
# Name: Value, Length: 256, dtype: float64

# %% [markdown]
# # 1. Assginment question
# # To Calculate gdp of world in year 1969 we can seethat it is 2.690798e+12

# %%
df_pr=df[df["Country Name"]=="World"]
df_pr=df_pr[df_pr["Year"]==1969]

# %%
df_pr.head()
# Out:
#      Country Name Country Code  Year         Value    GDP
# 2258        World          WLD  1969  2.690798e+12  10.13
# 2258        World          WLD  1969  2.690798e+12  10.13
# 2258        World          WLD  1969  2.690798e+12  10.13
# 2258        World          WLD  1969  2.690798e+12  10.13
# 2258        World          WLD  1969  2.690798e+12  10.13

# %%
df_pr=df[df["Country Name"]=="India"]
df_pr=df_pr[df_pr["Year"]==1993]

# %%
round(2.755704e+11)
# Out:
# 275570400000

# %%
df_pr.head()
# Out:
#      Country Name Country Code  Year         Value   GDP
# 6107        India          IND  1993  2.755704e+11 -3.09
# 6107        India          IND  1993  2.755704e+11 -3.09
# 6107        India          IND  1993  2.755704e+11 -3.09
# 6107        India          IND  1993  2.755704e+11 -3.09
# 6107        India          IND  1993  2.755704e+11 -3.09

# %%
round(3.229099e+11)

# %%
df_pr=df[df["Country Name"]=="India"]
df_pr=df_pr[df_pr["Year"]==1994]

# %%
df_pr.head()

# %% [markdown]
# from above two two table we can see thee gdp of year .
# 1993-->275570400000
# 1994-->322909900000

# %% [markdown]
# # % of GDP Growth in india from 1993 to 1994

# %%
# Hence there is 17% growth in the gdp from year 1993 to 19948
round(((322909900000-275570400000)/275570400000)*100)

# %% [markdown]
# # GDP Growth of india from 1960 to 2016

# %%
df_pr=df[df["Country Name"]=="India"]
df_pr=df_pr[df_pr["Year"]==1960]

# %%
df_pr.head()
#1960-->3653593

# %%
df_pr=df[df["Country Name"]=="India"]
df_pr=df_pr[df_pr["Year"]==2016]

# %%
df_pr.head()
#2016-->2263792

# %% [markdown]
# # From here we can see that the there is 38 percent decrease in gdp from 1960 to 2016

# %%
round(((2263792-3653593)/3653593)*100)

# %% [markdown]
# # GDP Growth Chart of India from 1960 to 2016

# %%
df_pa=df[df["Country Name"]=="India"]
fig=px.line(df_pa,x="Year",y="Value",title="GDP Of India")

fig
# Out:
# <div>                            <div id="182c1404-6f4a-436b-8fe7-2f1931ff2e74" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("182c1404-6f4a-436b-8fe7-2f1931ff2e74")) {                    Plotly.newPlot(                        "182c1404-6f4a-436b-8fe7-2f1931ff2e74",                        [{"hovertemplate":"Year=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":[1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,20
# ...
